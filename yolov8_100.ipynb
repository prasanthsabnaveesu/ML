# %% [markdown]
# <a href="https://colab.research.google.com/github/prasanthsabnaveesu/Machine-Learning/blob/master/yolov8_100.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 612.0/612.0 kB 16.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import yolo

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!unzip https://drive.google.com/drive/my-drive/Wind turbine_yolov8.zip

# %%
# !pip install roboflow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 18.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 kB 5.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.5 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=c72d87439ad741bc7f0b62759ed1422f5ddcd52d974118a60bf0823015e1f22d
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
# ...

# %%
# !pip freeze
# Out:
# absl-py==1.4.0
# alabaster==0.7.13
# albumentations==1.2.1
# altair==4.2.2
# anyio==3.7.0
# appdirs==1.4.4
# argon2-cffi==21.3.0
# argon2-cffi-bindings==21.2.0
# array-record==0.3.0
# arviz==0.15.1
# astropy==5.2.2
# astunparse==1.6.3
# attrs==23.1.0
# audioread==3.0.0
# autograd==1.5
# Babel==2.12.1
# backcall==0.2.0
# beautifulsoup4==4.11.2
# bleach==6.0.0
# blis==0.7.9
# blosc2==2.0.0
# bokeh==2.4.3
# branca==0.6.0
# build==0.10.0
# CacheControl==0.13.1
# cached-property==1.5.2
# cachetools==5.3.1
# catalogue==2.0.8
# certifi==2022.12.7
# cffi==1.15.1
# chardet==4.0.0
# charset-normalizer==2.0.12
# chex==0.1.7
# click==8.1.3
# cloudpickle==2.2.1
# cmake==3.25.2
# cmdstanpy==1.1.0
# colorcet==3.0.1
# colorlover==0.3.0
# community==1.0.0b1
# confection==0.0.4
# cons==0.4.5
# contextlib2==0.6.0.post1
# contourpy==1.1.0
# convertdate==2.4.0
# cryptography==41.0.1
# cufflinks==0.17.3
# cupy-cuda11x==11.0.0
# cvxopt==1.3.1
# cvxpy==1.3.1
# cycler==0.10.0
# cymem==2.0.7
# ...

# %%
from roboflow import Roboflow

rf = Roboflow(api_key="QEEGhsBoBfxeWLhndSd6")
project = rf.workspace().project("wind-turbine-wmk9p")
model = project.version(14).download("yolov8")
'''
# infer on a local image
print(model.predict("your_image.jpg").json())

# infer on an image hosted elsewhere
print(model.predict("URL_OF_YOUR_IMAGE").json())

# save an image annotated with your predictions
model.predict("your_image.jpg").save("prediction.jpg")
'''
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics<=8.0.20 is required but found version=8.0.122, to fix: `pip install ultralytics<=8.0.20`
# ...
# Extracting Dataset Version Zip to Wind-turbine-14 in yolov8:: 100%|██████████| 5346/5346 [00:01<00:00, 3304.57it/s]
# '\n# infer on a local image\nprint(model.predict("your_image.jpg").json())\n\n# infer on an image hosted elsewhere\nprint(model.predict("URL_OF_YOUR_IMAGE").json())\n\n# save an image annotated with your predictions\nmodel.predict("your_image.jpg").save("prediction.jpg")\n'

# %%
# !yolo task=detect mode=train model=yolov8x.pt data='/content/Wind-turbine-14/data.yaml' epochs=100 imgsz=640
# Out:
# ...
# 100% 131M/131M [00:05<00:00, 23.9MB/s]
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # val

# %%
# !yolo task=detect mode=val model='/content/runs/detect/train/weights/best.pt' data='/content/Wind-turbine-14/data.yaml'
# Out:
# Ultralytics YOLOv8.0.122 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68127420 parameters, 0 gradients
# val: Scanning /content/Wind-turbine-14/valid/labels.cache... 100 images, 0 backgrounds, 0 corrupt: 100% 100/100 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 7/7 [00:09<00:00,  1.38s/it]
#                    all        100        117      0.921       0.96      0.974      0.801
#           edge_erosion        100         13       0.92          1      0.995      0.946
#      lighting_receptor        100         31      0.946      0.935      0.978      0.715
#         surface_damage        100         41      0.881      0.904      0.929      0.633
#               vg_panel        100         32      0.939          1      0.995      0.912
# Speed: 10.1ms preprocess, 58.1ms inference, 0.0ms loss, 4.3ms postprocess per image
# Results saved to runs/detect/val

# %% [markdown]
#  # Test

# %%
# !yolo task=detect mode=predict model='/content/runs/detect/train/weights/best.pt' conf=0.25 source='/content/Wind-turbine-14/test/images' save=True
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/cfg/__init__.py", line 378, in entrypoint
#     model = YOLO(model, task=task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 107, in __init__
#     self._load(model, task)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/yolo/engine/model.py", line 156, in _load
#     self.model, self.ckpt = attempt_load_one_weight(weights)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 578, in attempt_load_one_weight
#     ckpt, weight = torch_safe_load(weight)  # load ckpt
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/nn/tasks.py", line 518, in torch_safe_load
#     return torch.load(file, map_location='cpu'), file  # load
# ...

# %% [markdown]
# # Segment val

# %%
# !yolo task=segment mode=val model='/content/runs/detect/train/weights/best.pt' data='/content/Wind-turbine-14/data.yaml'

# %% [markdown]
# # Segment test

# %%
# !yolo task=segment mode=predict model='/content/runs/detect/train/weights/best.pt' conf=0.25 source='/content/Wind-turbine-14/test/images' save=True

# %% [markdown]
# # Image view

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'content/runs/detect/predict3/*.jpg')[:5]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %% [markdown]
# Deploy model on Roboflow
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the /runs/detect/train/weights/best.pt folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The .deploy() function in the Roboflow pip package now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a9cef1c7d00d> in <cell line: 1>()
# ----> 1 project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
#
# NameError: name 'dataset' is not defined

# %%
#Run inference on your model on a persistant, auto-scaling, cloud API

#load model
model = project.version(dataset.version).model

#choose random test set image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
